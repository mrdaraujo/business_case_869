# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (1.9.2)
# Requirement already satisfied: tzlocal in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (4.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (4.11.4)
# Requirement already satisfied: tornado>=5.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (6.1)
# Requirement already satisfied: protobuf<4,>=3.12 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (3.20.1)
# Requirement already satisfied: cachetools>=4.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: requests in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (2.27.1)
# Requirement already satisfied: validators in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (0.19.0)
# Requirement already satisfied: packaging in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (21.3)
# Requirement already satisfied: altair>=3.2.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: numpy in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (1.22.4)
# Requirement already satisfied: pyarrow in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (8.0.0)
# Requirement already satisfied: pympler>=0.9 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: click<8.1,>=7.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: pandas>=0.21.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (9.1.1)
# Requirement already satisfied: typing-extensions in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: attrs in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (21.4.0)
# Requirement already satisfied: python-dateutil in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: blinker in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (1.4)
# Requirement already satisfied: semver in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: gitpython!=3.1.19 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: toml in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (4.5.1)
# Requirement already satisfied: toolz in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: entrypoints in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from pandas>=0.21.0->streamlit) (2022.1)
# Requirement already satisfied: traitlets>=4.3.2 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (5.2.1.post0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (7.7.0)
# Requirement already satisfied: ipykernel>=5.1.2 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (6.13.0)
# Requirement already satisfied: six>=1.5 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from packaging->streamlit) (3.0.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from requests->streamlit) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from requests->streamlit) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from requests->streamlit) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from requests->streamlit) (3.3)
# Requirement already satisfied: backports.zoneinfo in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from tzlocal->streamlit) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from tzlocal->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from validators->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.6.0)
# Requirement already satisfied: psutil in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.9.1)
# Requirement already satisfied: nest-asyncio in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.5)
# Requirement already satisfied: ipython>=7.23.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (8.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.3)
# Requirement already satisfied: appnope in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.3.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (5.7.1)
# Requirement already satisfied: tzdata in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from pytz-deprecation-shim->tzlocal->streamlit) (2022.1)
# Requirement already satisfied: setuptools>=18.5 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (56.0.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.12.0)
# Requirement already satisfied: pexpect>4.3 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.29)
# Requirement already satisfied: stack-data in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: backcall in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.10.0)
# Requirement already satisfied: pyzmq>=22.3 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (23.0.0)
# Requirement already satisfied: fastjsonschema in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.15.3)
# Requirement already satisfied: notebook>=4.4.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.15.0)
# Requirement already satisfied: prometheus-client in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.14.1)
# Requirement already satisfied: argon2-cffi in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: pure-eval in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.2)
# Requirement already satisfied: asttokens in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.0.5)
# Requirement already satisfied: executing in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.1.1)
# Requirement already satisfied: bleach in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.0)
# Requirement already satisfied: defusedxml in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.11.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pycparser in /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import numpy as np
import pandas as pd

# %% [markdown]
# # Create the user interface

# %% [markdown]
# ## Use streamlit for the app

# %%
st.markdown("""# Business Case - 869
## Prediction and analysis of sales in Favorita stores located in Ecuador
Presentation of our project""")
# Out:
# 2022-06-01 12:20:58.093
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/farahboukitab/.pyenv/versions/3.8.13/envs/business_case_869/lib/python3.8/site-packages/ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
### Load csv dataset
data_train = pd.read_csv("/Users/farahboukitab/code/mrdaraujo/business_case_869/business_case_869/data/store-sales-time-series-forecasting/train.csv")
data_stores = pd.read_csv("/Users/farahboukitab/code/mrdaraujo/business_case_869/business_case_869/data/store-sales-time-series-forecasting/stores.csv")
#merge train dataset and stores dataset
data_train_merge_stores = pd.merge(data_train, data_stores, on="store_nbr")
data_train_merge_stores['date'] = pd.to_datetime(data_train_merge_stores['date'])
#create baseline dataset
data_baseline = data_train_merge_stores
data_baseline['month'] = data_baseline['date'].dt.month
data_baseline['year'] = data_baseline['date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 ### Load csv dataset
# ----> 2 data_train = pd.read_csv("/Users/farahboukitab/code/mrdaraujo/business_case_869/business_case_869/data/store-sales-time-series-forecasting/train.csv")
#       3 data_stores = pd.read_csv("/Users/farahboukitab/code/mrdaraujo/business_case_869/business_case_869/data/store-sales-time-series-forecasting/stores.csv")
#       4 #merge train dataset and stores dataset
#
# NameError: name 'pd' is not defined

# %%
# this slider allows the user to select a number of lines
# to display in the dataframe
# the selected value is returned by st.slider
line_count = st.slider('Select a line count', 1, 100000, 100)
# and used in order to select the displayed lines
display_df = data_baseline.head(line_count)
display_df
# Out:
#       id       date  store_nbr                      family      sales  \
# 0      0 2013-01-01          1                  AUTOMOTIVE   0.000000
# 1      1 2013-01-01          1                   BABY CARE   0.000000
# 2      2 2013-01-01          1                      BEAUTY   0.000000
# 3      3 2013-01-01          1                   BEVERAGES   0.000000
# 4      4 2013-01-01          1                       BOOKS   0.000000
# ..   ...        ...        ...                         ...        ...
# 95  3593 2013-01-03          1              PREPARED FOODS  63.000000
# 96  3594 2013-01-03          1                     PRODUCE   0.000000
# 97  3595 2013-01-03          1  SCHOOL AND OFFICE SUPPLIES   0.000000
# 98  3596 2013-01-03          1                     SEAFOOD  17.366001
# 99  5346 2013-01-04          1                  AUTOMOTIVE   3.000000
#
#     onpromotion   city      state type  cluster  month  year
# 0             0  Quito  Pichincha    D       13      1  2013
# 1             0  Quito  Pichincha    D       13      1  2013
# 2             0  Quito  Pichincha    D       13      1  2013
# 3             0  Quito  Pichincha    D       13      1  2013
# 4             0  Quito  Pichincha    D       13      1  2013
# ..          ...    ...        ...  ...      ...    ...   ...
# 95            0  Quito  Pichincha    D       13      1  2013
# 96            0  Quito  Pichincha    D       13      1  2013
# 97            0  Quito  Pichincha    D       13      1  2013
# 98            0  Quito  Pichincha    D       13      1  2013
# 99            0  Quito  Pichincha    D       13      1  2013
#
# [100 rows x 12 columns]
